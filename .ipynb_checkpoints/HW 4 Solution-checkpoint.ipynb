# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns
# %matplotlib inline

# set file path
whale_returns_path = Path("Resources/whale_returns.csv")
algo_returns_path = Path("Resources/algo_returns.csv")
sp500_returns_path = Path("Resources/sp500_history.csv")

whale_return = pd.read_csv(whale_returns_path, index_col='Date', parse_dates=True, infer_datetime_format=True)
algo_return = pd.read_csv(algo_returns_path, index_col='Date', parse_dates=True, infer_datetime_format=True)
sp500_close_price = pd.read_csv(sp500_returns_path, index_col='Date', parse_dates=True, infer_datetime_format=True)

# read a few rows of data
whale_return.head()
whale_return.tail()
algo_return.head()
algo_return.tail()
sp500_close_price.head()
sp500_close_price.tail()

# clean data - drop nulls and convert sp500 data in the ascending date order as well as calculate the daily return

whale_return.isnull().sum()
whale_return = whale_return.dropna()
whale_return.isnull().sum()

algo_return.isnull().sum()
algo_return = algo_return.dropna()
algo_return.isnull().sum()

sp500_close_price.sort_index(ascending=True)
sp500_close_price.tail()
sp500_close_price["Close"] = sp500_close_price["Close"].str.replace("$", "")
sp500_close_price = sp500_close_price.astype(float)
sp500_close_price.dtypes
sp500_return = sp500_close_price.pct_change()
sp500_return.isnull().sum()
sp500_return = sp500_return.dropna()
sp500_return.isnull().sum()
sp500_return = sp500_return.rename(columns={"Close":"SP500"})
sp500_return.head()

# combine all three portfolio returns into one data frame.

whale_algo_sp500_daily_return = pd.concat([whale_return, algo_return, sp500_return], axis = "columns", join = "inner")
whale_algo_sp500_daily_return.head()
whale_algo_sp500_daily_return.tail()

# performance analysis - plot daily return on each portfolio

#whale_algo_sp500_daily_return.plot(figsize=(20,10), title="Daily Returns")

# performance analysis - calculate and plot the cumulative return on each portfolio

whale_algo_sp500_cumulative_return = (1 + whale_algo_sp500_daily_return).cumprod()
#whale_algo_sp500_cumulative_return.plot(figsize=(20,10), title="Cumulative Returns")

# risk analysis - create a box plot for each portfolio

#whale_algo_sp500_daily_return.plot.box(figsize=(20,10), title="Daily Returns")
#whale_algo_sp500_cumulative_return.plot.box(figsize=(20,10), title="Cumulative Returns")

# risk analysis - calculate the daily standard deviation for each portfolio

daily_std = whale_algo_sp500_daily_return.std()

# risk analysis - determine which portfolio is riskier than SP500 by comparing its sd.

daily_std.sort_values(ascending=True)
print(daily_std)
print(f"Tiger and Berkshire are riskier than SP500.")

# risk abalysis - calculate annualized sd for each portfolio

annualized_daily_std = daily_std * np.sqrt(252)

# rolling stats - calculate and plot a 21 days window rolling std

rolling_21days_std = whale_algo_sp500_daily_return.rolling(window=21).std()
#print(rolling_21days_std)

#rolling_21days_std.plot(figsize=(20,10), title="Rolling 21-Days Standard Deviation")

#calculate and plot the correlation

correlation = whale_algo_sp500_daily_return.corr()
#print(correlation)
#sns.heatmap(correlation, vmax=1, vmin=-1)

# calculate and plot beta of algo1 and sp500

algo1_covariance = whale_algo_sp500_daily_return["Algo 1"].cov(whale_algo_sp500_daily_return["SP500"])
sp500_variance = whale_algo_sp500_daily_return["SP500"].var()
algo1_beta = algo1_covariance / sp500_variance

rolling_algo1_covariance = whale_algo_sp500_daily_return["Algo 1"].rolling(window=21).cov(whale_algo_sp500_daily_return["SP500"])
rolling_sp500_variance = whale_algo_sp500_daily_return["SP500"].rolling(window=21).var()
rolling_algo1_beta = rolling_algo1_covariance / rolling_sp500_variance
#rolling_algo1_beta.plot(figsize=(20,10),title="Rolling 21-Day Beta of Algo 1")

# rolling stats challenge - calculate the exponentially weighted average

whale_algo_sp500_daily_return.ewm(halflife='21 days', times=whale_algo_sp500_daily_return.index).mean()

# sharp ratio - annualize and plot

sharp_ratio = whale_algo_sp500_daily_return.mean() * 252 / (whale_algo_sp500_daily_return.std() * np.sqrt(252))

sharp_ratio.plot(kind="bar", figsize=(20,10), title="Sharp Ratio")

print("Yes, Algo 1 outperformed the Whales portfolios and S&P 500. Algo 2 outperformed all except Berkshire.")

whale_algo_sp500_daily_return.head()
# Out:
# SOROS FUND MANAGEMENT LLC      0.007896
# PAULSON & CO.INC.              0.007026
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007623
# Algo 2                         0.008341
# SP500                          0.008587
# dtype: float64
# Tiger and Berkshire are riskier than SP500.
# Yes, Algo 1 outperformed the Whales portfolios and S&P 500. Algo 2 outperformed all except Berkshire.
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# ...

# %%
# custom portfolio

estc_data = Path("Resources/estc.csv")
okta_data = Path("Resources/okta.csv")
pypl_data = Path("Resources/pypl.csv")
spot_data = Path("Resources/spot.csv")
v_data = Path("Resources/v.csv")

estc = pd.read_csv(estc_data)
estc["Date"] = pd.to_datetime(estc["Date"]).dt.date
estc.index = estc["Date"]
estc = estc.drop(columns=["Date"])

okta = pd.read_csv(okta_data)
okta["Date"] = pd.to_datetime(okta["Date"]).dt.date
okta.index = okta["Date"]
okta = okta.drop(columns=["Date"])

pypl = pd.read_csv(pypl_data)
pypl["Date"] = pd.to_datetime(pypl["Date"]).dt.date
pypl.index = pypl["Date"]
pypl = pypl.drop(columns=["Date"])

spot = pd.read_csv(spot_data)
spot["Date"] = pd.to_datetime(spot["Date"]).dt.date
spot.index = spot["Date"]
spot = spot.drop(columns=["Date"])

v = pd.read_csv(v_data)
v["Date"] = pd.to_datetime(v["Date"]).dt.date
v.index = v["Date"]
v = v.drop(columns=["Date"])

custom = pd.concat([okta, pypl,spot,v], axis = "columns", join = "inner")
custom.isnull().sum()
custom = custom.dropna()
custom.tail()

custom_daily_return = custom.pct_change()
custom_daily_return.head()
custom_daily_return = custom_daily_return.dropna()
custom_daily_return.isnull().sum()


weights = [1/4, 1/4, 1/4, 1/4]

weighted_custom_daily_return = custom_daily_return.dot(weights)

custom_added_return = pd.concat([whale_algo_sp500_daily_return, weighted_custom_daily_return], axis = "columns", join = "inner")
custom_added_return.isnull().sum()
custom_added_return = custom_added_return.rename(columns={0:"Custom"})
custom_added_return.tail()

# risk abalysis - calculate annualized sd for custom portfolio

annualized_custom_std = weighted_custom_daily_return.std() * np.sqrt(252)

# rolling stats - calculate and plot a 21 days window rolling std

rolling_21days_custom_std = weighted_custom_daily_return.rolling(window=21).std()

#correlation
#sns.heatmap(custom_added_return.corr(), vmax = "1", vmin = "-1")

#beta
rolling_custom_covariance = weighted_custom_daily_return.rolling(window=60).cov(whale_algo_sp500_daily_return["SP500"])
rolling_custom_beta = rolling_custom_covariance / rolling_sp500_variance
#rolling_custom_beta.plot(figsize=(20,10), title="Rolling 60 Days Beta of custom portfolio compare to S&P 500")

#annualized sharp ratio
sharp_ratio_with_custom = custom_added_return.mean() * 252 / (custom_added_return.std() * np.sqrt(252))
sharp_ratio_with_custom.plot(kind="bar", figsize=(20,10), title="Sharp Ratio with Custom Portfolio")
# Out:
# <AxesSubplot:title={'center':'Sharp Ratio with Custom Portfolio'}>
